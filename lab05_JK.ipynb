# %%
import arviz as az
import pymc3 as pm
import numpy as np

ones = np.ones(703)
zeros = np.zeros(301)
occurrences = np.concatenate((ones, zeros))

with pm.Model() as model:
    p = pm.Uniform("p", lower=0, upper=1)
    obs = pm.Bernoulli("obs", p, observed=occurrences)
    idata = pm.sample(2000, tune=2500)
az.plot_trace(idata, show=True)
# Out:
# /home/lab/mpad/16/PycharmProjects/pythonProject/venv/lib/python3.10/site-packages/deprecat/classic.py:215: FutureWarning: In v4.0, pm.sample will return an `arviz.InferenceData` object instead of a `MultiTrace` by default. You can pass return_inferencedata=True or return_inferencedata=False to be safe and silence this warning.
#   return wrapped_(*args_, **kwargs_)
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [p]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='18000' class='' max='18000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [18000/18000 00:02&lt;00:00 Sampling 4 chains, 0 divergences]
#     </div>
# Sampling 4 chains for 2_500 tune and 2_000 draw iterations (10_000 + 8_000 draws total) took 3 seconds.
# Got error No model on context stack. trying to find log_likelihood in translation.
# /home/lab/mpad/16/PycharmProjects/pythonProject/venv/lib/python3.10/site-packages/arviz/data/io_pymc3_3x.py:98: FutureWarning: Using `from_pymc3` without the model will be deprecated in a future release. Not using the model will return less accurate and less useful results. Make sure you use the model argument or call from_pymc3 within a model context.
#   warnings.warn(
# Got error No model on context stack. trying to find log_likelihood in translation.
# array([[<AxesSubplot: title={'center': 'p'}>,
#         <AxesSubplot: title={'center': 'p'}>]], dtype=object)
